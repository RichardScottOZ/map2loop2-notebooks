# %%
import h5py

# %%
filename = r'J:\Loop3D-v0.1.1\Loop3D\saBase.loop3d'

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[2]

    # Get the data
    data = list(f[a_group_key])
# Out:
# Keys: <KeysViewHDF5 ['DataCollection', 'ExtractedInformation', 'StructuralModels']>

# %%
def traverse_datasets(hdf_file):

    def h5py_dataset_iterator(g, prefix=''):
        for key in g.keys():
            item = g[key]
            path = f'{prefix}/{key}'
            if isinstance(item, h5py.Dataset): # test for dataset
                yield (path, item)
            elif isinstance(item, h5py.Group): # test for group (go down)
                print("GROUP:", item, "\n")
                yield from h5py_dataset_iterator(item, path)

    for path, _ in h5py_dataset_iterator(hdf_file):
        yield path
#You can, for example, iterate all dataset paths and output attributes which interest you:

with h5py.File(filename, 'r') as f:
    for dset in traverse_datasets(f):
        print('Path:', dset)
        print('Shape:', f[dset].shape)
        print('Data type:', f[dset].dtype)
        
        #print('Path:', dset)
        if dset == "/StructuralModels/data":
            print(dset)
            print(dset[:])
            print(f[dset][:].shape)
            print(f[dset][:])
# Out:
# GROUP: <HDF5 group "/DataCollection" (2 members)>
#
# GROUP: <HDF5 group "/DataCollection/Contacts" (3 members)>
#
# Path: /DataCollection/Contacts/index
# Shape: (0,)
# Data type: >f4
# Path: /DataCollection/Contacts/contacts
# Shape: (1519,)
# Data type: {'names':['layerId','easting','northing','altitude','type'], 'formats':['<u4','<f8','<f8','<f8','<i4'], 'offsets':[0,8,16,24,32], 'itemsize':40}
# GROUP: <HDF5 group "/DataCollection/Observations" (15 members)>
#
# Path: /DataCollection/Observations/faultObservationIndex
# Shape: (0,)
# Data type: >f4
# Path: /DataCollection/Observations/foldObservationIndex
# Shape: (0,)
# Data type: >f4
# Path: /DataCollection/Observations/foliationObservationIndex
# Shape: (0,)
# Data type: >f4
# Path: /DataCollection/Observations/discontinuityObservationIndex
# Shape: (0,)
# Data type: >f4
# Path: /DataCollection/Observations/stratigraphicObservationIndex
# Shape: (0,)
# Data type: >f4
# Path: /DataCollection/Observations/faultObservations
# Shape: (0,)
# Data type: {'names':['eventId','easting','northing','altitude','type','dipDir','dip','dipPolarity','val','displacement','posOnly'], 'formats':['<u4','<f8','<f8','<f8','<i4','<f8','<f8','<f8','<f8','<f8','u1'], 'offsets':[0,8,16,24,32,40,48,56,64,72,80], 'itemsize':88}
# Path: /DataCollection/Observations/foldObservations
# Shape: (0,)
# Data type: {'names':['eventId','easting','northing','altitude','type','axisX','axisY','axisZ','foliation','whatIsFolded'], 'formats':['<u4','<f8','<f8','<f8','<i4','<f8','<f8','<f8',('S1', (30,)),('S1', (30,))], 'offsets':[0,8,16,24,32,40,48,56,64,94], 'itemsize':128}
# Path: /DataCollection/Observations/foliationObservations
# Shape: (0,)
# Data type: {'names':['eventId','easting','northing','altitude','type','dipDir','dip'], 'formats':['<u4','<f8','<f8','<f8','<i4','<f8','<f8'], 'offsets':[0,8,16,24,32,40,48], 'itemsize':56}
# Path: /DataCollection/Observations/discontinuityObservations
# Shape: (0,)
# Data type: {'names':['eventId','easting','northing','altitude','type','dipDir','dip'], 'formats':['<u4','<f8','<f8','<f8','<i4','<f8','<f8'], 'offsets':[0,8,16,24,32,40,48], 'itemsize':56}
# Path: /DataCollection/Observations/stratigraphicObservations
# Shape: (3102,)
# Data type: {'names':['layerId','easting','northing','altitude','type','dipDir','dip','dipPolarity','layer'], 'formats':['<u4','<f8','<f8','<f8','<i4','<f8','<f8','<f8',('S1', (30,))], 'offsets':[0,8,16,24,32,40,48,56,64], 'itemsize':96}
# GROUP: <HDF5 group "/ExtractedInformation" (1 members)>
#
# GROUP: <HDF5 group "/ExtractedInformation/StratigraphicInformation" (3 members)>
#
# Path: /ExtractedInformation/StratigraphicInformation/index
# Shape: (0,)
# Data type: >f4
# Path: /ExtractedInformation/StratigraphicInformation/stratigraphicLayers
# Shape: (6,)
# Data type: {'names':['layerId','minAge','maxAge','name','supergroup','enabled','rank','type','thickness','colour1Red','colour1Green','colour1Blue','colour2Red','colour2Green','colour2Blue'], 'formats':['<u4','<f8','<f8',('S1', (30,)),('S1', (30,)),'u1','<u4','<i4','<f8','u1','u1','u1','u1','u1','u1'], 'offsets':[0,8,16,24,54,84,88,92,96,104,105,106,107,108,109], 'itemsize':112}
# GROUP: <HDF5 group "/StructuralModels" (8 members)>
#
# Path: /StructuralModels/easting
# Shape: (70,)
# Data type: >f4
# Path: /StructuralModels/northing
# Shape: (55,)
# Data type: >f4
# Path: /StructuralModels/depth
# Shape: (45,)
# Data type: >f4
# Path: /StructuralModels/index
# Shape: (0,)
# Data type: >f4
# Path: /StructuralModels/data
# Shape: (70, 55, 45, 1)
# Data type: float32
# /StructuralModels/data
# /StructuralModels/data
# (70, 55, 45, 1)
# [[[[-10373.366 ]
#    [-10549.474 ]
#    [-10730.5625]
#    ...
#    [ -8915.975 ]
#    [ -9010.802 ]
#    [ -9025.989 ]]
#
#   [[ -9034.643 ]
#    [ -8971.473 ]
#    [ -8892.7   ]
#    ...
#    [ -9766.346 ]
#    [ -9854.893 ]
#    [ -9978.388 ]]
#
#   [[-10134.119 ]
#    [-10255.6045]
#    [-10357.297 ]
#    ...
#    [ -8625.41  ]
#    [ -8622.111 ]
#    [ -8651.083 ]]
#
#   ...
#
#   [[ -8622.805 ]
#    [ -8572.    ]
#    [ -8522.512 ]
#    ...
#    [-11056.826 ]
#    [-11119.234 ]
#    [-11162.468 ]]
#
#   [[-11205.88  ]
#    [-11226.331 ]
#    [-11239.423 ]
#    ...
#    [ -8246.742 ]
#    [ -8221.777 ]
#    [ -8203.264 ]]
#
#   [[ -8198.078 ]
#    [ -8187.5225]
#    [ -8170.5356]
#    ...
#    [ -8907.828 ]
#    [ -8848.374 ]
#    [ -8794.255 ]]]
#
#
#  [[[ -8769.157 ]
#    [ -8745.984 ]
#    [ -8724.588 ]
#    ...
#    [ -7548.2446]
#    [ -7549.0454]
#    [ -7543.341 ]]
#
#   [[-10876.947 ]
#    [-10940.445 ]
#    [-10989.772 ]
#    ...
#    [ -8683.687 ]
#    [ -8588.884 ]
#    [ -8498.758 ]]
#
#   [[ -8412.111 ]
#    [ -8347.864 ]
#    [ -8294.315 ]
#    ...
#    [ -9755.485 ]
#    [ -9546.363 ]
#    [ -9361.782 ]]
#
#   ...
#
#   [[ -8174.9873]
#    [ -8082.2397]
#    [ -7973.817 ]
#    ...
#    [ -9476.134 ]
#    [ -9282.756 ]
#    [ -9042.004 ]]
#
#   [[ -8803.374 ]
#    [ -8582.389 ]
#    [ -8390.81  ]
#    ...
#    [-11485.39  ]
#    [-11630.429 ]
#    [-11753.475 ]]
#
#   [[-11873.557 ]
#    [-11913.577 ]
#    [-11936.285 ]
#    ...
#    [ -8318.103 ]
#    [ -8365.191 ]
#    [ -8396.704 ]]]
#
#
#  [[[ -8392.363 ]
#    [ -8377.64  ]
#    [ -8328.342 ]
#    ...
#    [ -9520.546 ]
#    [ -9618.827 ]
#    [ -9715.658 ]]
#
#   [[ -9688.085 ]
#    [ -9643.676 ]
#    [ -9479.085 ]
#    ...
#    [ -7046.4893]
#    [ -7083.448 ]
#    [ -7143.213 ]]
#
#   [[-11257.077 ]
#    [-11392.9795]
#    [-11531.331 ]
#    ...
#    [ -7850.3745]
#    [ -7842.902 ]
#    [ -7897.159 ]]
#
#   ...
#
#   [[-11207.901 ]
#    [-11145.895 ]
#    [-11075.535 ]
#    ...
#    [ -7511.8745]
#    [ -7460.6514]
#    [ -7392.7974]]
#
#   [[ -7309.6143]
#    [ -7217.555 ]
#    [ -7124.505 ]
#    ...
#    [ -8315.83  ]
#    [ -8180.4053]
#    [ -8094.7393]]
#
#   [[ -8028.1177]
#    [ -8003.3594]
#    [ -8010.1465]
#    ...
#    [-11919.638 ]
#    [-11885.257 ]
#    [-11826.36  ]]]
#
#
#  ...
#
#
#  [[[ -3539.6921]
#    [ -4083.0298]
#    [ -4621.995 ]
#    ...
#    [ -2346.8274]
#    [ -2612.7903]
#    [ -2952.414 ]]
#
#   [[ -3439.363 ]
#    [ -3933.5498]
#    [ -4412.0796]
#    ...
#    [ -3511.5256]
#    [ -2928.4011]
#    [ -2567.3408]]
#
#   [[ -2281.9438]
#    [ -2177.6162]
#    [ -2411.37  ]
#    ...
#    [ -4175.5444]
#    [ -3940.6357]
#    [ -3828.555 ]]
#
#   ...
#
#   [[ -2503.2139]
#    [ -2569.2131]
#    [ -2670.1458]
#    ...
#    [ -2242.9734]
#    [ -2120.54  ]
#    [ -2019.0402]]
#
#   [[ -4688.517 ]
#    [ -4714.094 ]
#    [ -4712.673 ]
#    ...
#    [ -3337.6033]
#    [ -3185.8875]
#    [ -3085.1235]]
#
#   [[ -2995.2048]
#    [ -2957.231 ]
#    [ -2936.7515]
#    ...
#    [ -3649.814 ]
#    [ -3382.9983]
#    [ -3136.0598]]]
#
#
#  [[[ -2907.8535]
#    [ -2738.168 ]
#    [ -2577.0483]
#    ...
#    [ -2062.392 ]
#    [ -2355.1416]
#    [ -2622.1313]]
#
#   [[ -2728.6548]
#    [ -2646.6853]
#    [ -2543.0732]
#    ...
#    [ -5680.6533]
#    [ -5375.496 ]
#    [ -4832.5786]]
#
#   [[ -4211.4043]
#    [ -3569.8413]
#    [ -3284.973 ]
#    ...
#    [ -4382.622 ]
#    [ -4407.729 ]
#    [ -4337.776 ]]
#
#   ...
#
#   [[ -3976.5935]
#    [ -4099.3667]
#    [ -4003.2131]
#    ...
#    [ -3298.1917]
#    [ -3985.6494]
#    [ -4671.4795]]
#
#   [[ -5149.4023]
#    [ -5519.4053]
#    [ -5225.1406]
#    ...
#    [ -1713.5966]
#    [ -1631.1841]
#    [ -1629.3663]]
#
#   [[ -4831.1094]
#    [ -4896.0127]
#    [ -5127.0215]
#    ...
#    [ -1711.7747]
#    [ -1298.8699]
#    [ -1448.353 ]]]
#
#
#  [[[ -1636.1106]
#    [ -1835.9534]
#    [ -2107.748 ]
#    ...
#    [ -1940.7432]
#    [ -1836.4171]
#    [ -1856.5262]]
#
#   [[ -1987.0146]
#    [ -2379.705 ]
#    [ -2796.8313]
#    ...
#    [ -2139.1555]
#    [ -2365.742 ]
#    [ -2529.8618]]
#
#   [[ -2442.1255]
#    [ -2264.289 ]
#    [ -2153.785 ]
#    ...
#    [ -2870.133 ]
#    [ -3534.745 ]
#    [ -4093.8257]]
#
#   ...
#
#   [[ -5975.4087]
#    [ -5829.892 ]
#    [ -5684.009 ]
#    ...
#    [ -1544.1002]
#    [ -1636.3396]
#    [ -1725.5193]]
#
#   [[ -1785.8427]
#    [ -1825.279 ]
#    [ -1845.2203]
#    ...
#    [ -4357.203 ]
#    [ -4016.9016]
#    [ -3639.051 ]]
#
#   [[ -3158.8486]
#    [ -2676.6626]
#    [ -2364.5845]
#    ...
#    [ -1056.4408]
#    [ -1032.6494]
#    [ -1005.2932]]]]
# Path: /StructuralModels/minVal
# Shape: (1,)
# Data type: float32
# Path: /StructuralModels/maxVal
# Shape: (1,)
# Data type: float32
# Path: /StructuralModels/valid
# Shape: (1,)
# Data type: |S1
